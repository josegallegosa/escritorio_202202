# %%
import pandas as pd

df = pd.read_csv('ubigeo_peru.csv')

# %%
df.head()
# Out:
#      id         id_xml  country_id      name  code  code_text  create_uid  \
# 0  1146  ubigeo_000001         173  Amazonas     1          1           1
# 1  1147  ubigeo_000002         173    Áncash     2          2           1
# 2  1148  ubigeo_000003         173  Apurímac     3          3           1
# 3  1149  ubigeo_000004         173  Arequipa     4          4           1
# 4  1150  ubigeo_000005         173  Ayacucho     5          5           1
#
#                   create_date  write_uid                  write_date  \
# 0  2022-02-03 03:31:07.188614          1  2022-02-03 03:31:07.188614
# 1  2022-02-03 03:31:07.188614          1  2022-02-03 03:31:07.188614
# 2  2022-02-03 03:31:07.188614          1  2022-02-03 03:31:07.188614
# 3  2022-02-03 03:31:07.188614          1  2022-02-03 03:31:07.188614
# 4  2022-02-03 03:31:07.188614          1  2022-02-03 03:31:07.188614
#
#    state_id departamento parent_id  province_id provincia complete_name
# ...

# %%
#for row in df.index:

# %%
import pandas as pd



for row in df.index:
    print(' ')
    print('<record forcecreate="True" id="'+'ubigeo_'+str(df['code_text'][row])+'" model="fsm.location">')
    print('    <field name="name">'+str(df['name'][row])+'</field>')
    print('    <field name="complete_name">'+str(df['complete_name'][row])+'</field>')
    print('    <field name="parent_id" ref="'+str(df['parent_id'][row])+'"/>')
    print('    <field name="owner_id" ref="res_partner_ubigeo_peru"/>')
    print('</record>')
# Out:
#
# <record forcecreate="True" id="ubigeo_1" model="fsm.location">
#     <field name="name">Amazonas</field>
#     <field name="complete_name">Amazonas</field>
#     <field name="parent_id" ref="nan"/>
#     <field name="owner_id" ref="res_partner_ubigeo_peru"/>
# </record>
#
# <record forcecreate="True" id="ubigeo_2" model="fsm.location">
#     <field name="name">Áncash</field>
#     <field name="complete_name">Áncash</field>
#     <field name="parent_id" ref="nan"/>
#     <field name="owner_id" ref="res_partner_ubigeo_peru"/>
# </record>
#
# <record forcecreate="True" id="ubigeo_3" model="fsm.location">
#     <field name="name">Apurímac</field>
#     <field name="complete_name">Apurímac</field>
#     <field name="parent_id" ref="nan"/>
#     <field name="owner_id" ref="res_partner_ubigeo_peru"/>
# </record>
#
# <record forcecreate="True" id="ubigeo_4" model="fsm.location">
#     <field name="name">Arequipa</field>
#     <field name="complete_name">Arequipa</field>
# ...

# %%
<odoo>
    <data noupdate="1">

        <record forcecreate="True" id="ubigeo_000001" model="fsm.location">    
            <field name="name">Amazonas</field>
            <field name="complete_name">Amazonas</field>
            <field name="owner_id" ref="res_partner_ubigeo_peru"/>
        </record> 
        
    </data>
</odoo>
